# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %% [markdown]
# Data Clean

# %%
asx_list = pd.read_csv('assets/ASX_companies_list.csv')
asx200_list = pd.read_csv('assets/ASX200_companies_list.csv')

# %%
asx200_list
# Out:
#     Code Yahoo Code                                       Company
# 0    A2M     A2M.AX                       The a2 Milk Company Ltd
# 1    AAA     AAA.AX  Betashares Australian High Interest Cash ETF
# 2    ABC     ABC.AX                                     Adbri Ltd
# 3    ABP     ABP.AX                         Abacus Property Group
# 4    AFI     AFI.AX  Australian Foundation Investment Company Ltd
# ..   ...        ...                                           ...
# 195  WTC     WTC.AX                           Wisetech Global Ltd
# 196  XRO     XRO.AX                                      Xero Ltd
# 197  YAL     YAL.AX                         Yancoal Australia Ltd
# 198  ZIP     ZIP.AX                                    ZIP Co Ltd
# 199  ZIM     ZIM.AX                         Zimplats Holdings Ltd
#
# [200 rows x 3 columns]

# %%
asx200_list = asx200_list.drop('Company', axis=1).merge(asx_list, on = ['Code', 'Yahoo Code'])

# %%
asx200_list
# Out:
#     Code Yahoo Code                                           Company  \
# 0    A2M     A2M.AX                       The A2 Milk Company Limited
# 1    AAA     AAA.AX      BetaShares Australian High Interest Cash ETF
# 2    ABC     ABC.AX                                     Adbri Limited
# 3    AFI     AFI.AX  Australian Foundation Investment Company Limited
# 4    AGL     AGL.AX                                AGL Energy Limited
# ..   ...        ...                                               ...
# 184  WTC     WTC.AX                           WiseTech Global Limited
# 185  XRO     XRO.AX                                      Xero Limited
# 186  YAL     YAL.AX                             Yancoal Australia Ltd
# 187  ZIP     ZIP.AX                                    Zip Co Limited
# 188  ZIM     ZIM.AX                         Zimplats Holdings Limited
#
#                      Sector   Market Cap  Total Shares  Last trade
# 0          Consumer Staples   2833900000  7.210941e+08       3.930
# 1                Financials   3334510000  6.639805e+07      50.220
# 2                 Materials   1332790000  6.501415e+08       2.050
# 3                Financials   8763240000  1.246549e+09       7.030
# 4                 Utilities   6680380000  6.707209e+08       9.960
# ..                      ...          ...           ...         ...
# 184  Information Technology  22048800000  3.442436e+08      64.050
# 185  Information Technology  15078900000  1.514554e+08      99.560
# 186                  Energy   6615400000  1.320439e+09       5.010
# 187              Financials    338657000  9.278274e+08       0.365
# 188               Materials   2185040000  1.076374e+08      20.300
#
# [189 rows x 7 columns]

# %% [markdown]
# Test yf

# %%
msft = yf.Ticker("MSFT")
data = msft.history(period="3mo", interval="1wk")

# %%
(data['Close'] - data['Open']) / data['Open'] * 100
# Out:
# pandas.core.series.Series

# %%
yf.Ticker("BHP.AX").history()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-10-24 00:00:00+11:00  43.599998  43.740002  43.380001  43.590000
# 2023-10-25 00:00:00+11:00  44.580002  44.900002  44.169998  44.720001
# 2023-10-26 00:00:00+11:00  44.790001  45.090000  44.540001  44.930000
# 2023-10-27 00:00:00+11:00  44.930000  45.189999  44.759998  45.060001
# 2023-10-30 00:00:00+11:00  45.500000  45.549999  44.939999  45.110001
